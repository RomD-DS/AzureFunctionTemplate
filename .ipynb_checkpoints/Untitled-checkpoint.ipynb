# %%
import msal
import requests

# App Registration
CLIENT_ID = "c8280fc0-7bad-4373-8e7e-da3567255da4"
TENANT_ID = "8b87af7d-8647-4dc7-8df4-5f69a2011bb5"
CLIENT_SECRET = "9c8afea5-ab5d-4478-9cf4-5f187ff5de42" 

AUTHORITY = f"https://login.microsoftonline.com/{TENANT_ID}"

# Permission pour lire les emails
SCOPES = ["https://graph.microsoft.com/.default"] 
# IMPORTANT: avec client_secret → toujours utiliser .default


# 1) Application MSAL en mode CONFIDENTIAL CLIENT
app = msal.ConfidentialClientApplication(
    client_id=CLIENT_ID,
    client_credential=CLIENT_SECRET,
    authority=AUTHORITY
)


# 2) Récupère un token
result = app.acquire_token_for_client(scopes=SCOPES)

if "access_token" not in result:
    print("Erreur :", result)
    raise SystemExit()

token = result["access_token"]


# 3) Appel vers Microsoft Graph
headers = {"Authorization": f"Bearer {token}"}

url = "https://graph.microsoft.com/v1.0/users/tonmail@tondomaine.com/messages?$top=10"

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# Erreur : {'error': 'invalid_client', 'error_description': "AADSTS7000215: Invalid client secret provided. Ensure the secret being sent in the request is the client secret value, not the client secret ID, for a secret added to app 'c8280fc0-7bad-4373-8e7e-da3567255da4'. Trace ID: 257f04af-6e13-4392-a82f-8eb794b89c00 Correlation ID: 1398623d-684b-4a3a-9187-4cbe6012bbf9 Timestamp: 2025-11-27 14:40:34Z", 'error_codes': [7000215], 'timestamp': '2025-11-27 14:40:34Z', 'trace_id': '257f04af-6e13-4392-a82f-8eb794b89c00', 'correlation_id': '1398623d-684b-4a3a-9187-4cbe6012bbf9', 'error_uri': 'https://login.microsoftonline.com/error?code=7000215'}
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\rodaniel\AppData\Local\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import msal
import requests

# Mets ici tes valeurs depuis App Registration
CLIENT_ID = "c8280fc0-7bad-4373-8e7e-da3567255da4"
TENANT_ID = "8b87af7d-8647-4dc7-8df4-5f69a2011bb5"

# Permission minimale
SCOPES = ["Mail.Read"]

# 1) App MSAL
app = msal.PublicClientApplication(
    client_id=CLIENT_ID,
    authority=f"https://login.microsoftonline.com/{TENANT_ID}"
)

# %%
# 2) Authentification Device Code (super simple)
flow = app.initiate_device_flow(scopes=SCOPES)
print(flow["message"])      # Tu cliques sur le lien et acceptes

result = app.acquire_token_by_device_flow(flow)

if "access_token" not in result:
    raise Exception("Impossible de se connecter :", result)

token = result["access_token"]

# 3) Lire 1 mail
url = "https://graph.microsoft.com/v1.0/me/messages?$top=1"
headers = {"Authorization": f"Bearer {token}"}

res = requests.get(url, headers=headers).json()

mail = res["value"][0]
print("\n===== MAIL =====")
print("From :", mail["from"]["emailAddress"]["address"])
print("Subject :", mail["subject"])
print("Preview :", mail["bodyPreview"])
# Out:
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code CW87QUWXN to authenticate.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 5
#       2 flow = app.initiate_device_flow(scopes=SCOPES)
#       3 print(flow["message"])      # Tu cliques sur le lien et acceptes
# ----> 5 result = app.acquire_token_by_device_flow(flow)
#       7 if "access_token" not in result:
#       8     raise Exception("Impossible de se connecter :", result)
#
# File ~\AppData\Local\miniconda3\lib\site-packages\msal\application.py:2293, in PublicClientApplication.acquire_token_by_device_flow(self, flow, claims_challenge, **kwargs)
#    2272 """Obtain token by a device flow object, with customizable polling effect.
#    2273
#    2274 :param dict flow:
#    (...)
#    2288     - an error response would contain "error" and usually "error_description".
#    2289 """
#    2290 telemetry_context = self._build_telemetry_context(
#    2291     self.ACQUIRE_TOKEN_BY_DEVICE_FLOW_ID,
#    2292     correlation_id=flow.get(self.DEVICE_FLOW_CORRELATION_ID))
# -> 2293 response = _clean_up(self.client.obtain_token_by_device_flow(
#    2294     flow,
#    2295     data=dict(
#    2296         kwargs.pop("data", {}),
#    2297         code=flow["device_code"],  # 2018-10-4 Hack:
#    2298             # during transition period,
#    2299             # service seemingly need both device_code and code parameter.
#    2300         claims=_merge_claims_challenge_and_capabilities(
#    2301             self._client_capabilities, claims_challenge),
#    2302         ),
#    2303     headers=telemetry_context.generate_headers(),
#    2304     **kwargs))
#    2305 if "access_token" in response:
#    2306     response[self._TOKEN_SOURCE] = self._TOKEN_SOURCE_IDP
#
# File ~\AppData\Local\miniconda3\lib\site-packages\msal\oauth2cli\oauth2.py:392, in Client.obtain_token_by_device_flow(self, flow, exit_condition, **kwargs)
#     390 if exit_condition(flow):
#     391     return result
# --> 392 time.sleep(1)
#
# KeyboardInterrupt:
